# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

from latent_static_env import GNNLatentStaticEnv
from eval import run_online_simulation_static, run_dynamic_simulation_fix, run_dynamic_simulation_retrain
import pandas as pd
import matplotlib.pyplot as plt
import torch
import numpy as np

from data_preprocessing import sample_triples
from data_preprocessing import build_dataset_static
from graphsage import GraphSAGE

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print("Using device:", device)

# rng = np.random.RandomState(42)
# data_path = r'data/ml-latest-small/ratings.csv'

# (
#     num_users,
#     num_items,
#     num_nodes,
#     edge_index,
#     train_set,
#     train_user_items,
#     test_pairs,
# ) = build_dataset_static(
#     data_path,
#     device=device,
# )
# print("Finish Loading all data.")

# model = GraphSAGE(num_nodes, emb_dim=64, n_layers=3).to(device)
# opt = torch.optim.Adam(model.parameters(), lr=5e-3, weight_decay=0)

# epochs = 100
# print("Model Training starts (GraphSAGE)")
# loss_history = model.fit(
#     edge_index=edge_index,
#     num_users=num_users,
#     num_items=num_items,
#     rng=rng,
#     sample_triples=sample_triples,
#     train_set=train_set,
#     optimizer=opt,
#     epochs=epochs,
#     device=device,
#     save_path=None,
# )

# model_path = "graphsage_model.pth"
# torch.save(model.state_dict(), model_path)
# print(f"GraphSAGE model saved to {model_path}")

# user_emb, item_emb = model.compute_embeddings(
#     edge_index=edge_index,
#     num_users=num_users,
#     device=device,
#     save_path="embeddings/graphsage_embeddings.pt",
# )
# Out:
# Using device: cuda
# Finish Loading all data.
# Model Training starts (GraphSAGE)
# 100%|██████████| 100/100 [06:25<00:00,  3.86s/it]
# GraphSAGE model saved to graphsage_model.pth

# %%
run_online_simulation_static(emb_path=r'embeddings/graphsage_embeddings.pt', save_path=r'results/online_static_graphsage_metrics.csv', num_online_steps = 300)
# Out:
# d:\Desktop\2025_Autumn\CS_224W\proj\code\eval.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   embeddings = torch.load(emb_path, map_location=device)
# ...

# %%
run_dynamic_simulation_fix(emb_path=r'embeddings/graphsage_embeddings.pt', save_path=r'results/online_dynamic_fix_graphsage_metrics.csv', num_steps = 300)
# Out:
# d:\Desktop\2025_Autumn\CS_224W\proj\code\eval.py:284: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   embeddings = torch.load(emb_path, map_location=torch_device)
# ...

# %%
run_dynamic_simulation_retrain(emb_path=r'embeddings/graphsage_embeddings.pt', save_path=r'results/online_dynamic_retrain_graphsage_metrics.csv', num_steps = 300)
# Out:
# d:\Desktop\2025_Autumn\CS_224W\proj\code\eval.py:440: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   embeddings = torch.load(emb_path, map_location=torch_device)
# ...
